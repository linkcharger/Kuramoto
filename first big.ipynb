# %%
import sympy as s


theta, K, r = s.symbols('theta, K, r')

# integrand = s.cos(theta) * math.g
# consEQ = s.Eq(1, K * s.integrate(integrand, -s. ..pi))


s.pi()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       8
#       9
# ---> 10 s.pi()
#
# TypeError: 'Pi' object is not callable

# %%
import sympy as s


theta, K, r = s.symbols('theta, K, r')

# integrand = s.cos(theta) * math.g
# consEQ = s.Eq(1, K * s.integrate(integrand, -s. ..pi))


s.Pi()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       8
#       9
# ---> 10 s.Pi()
#
# AttributeError: module 'sympy' has no attribute 'Pi'

# %%
import sympy as s


theta, K, r = s.symbols('theta, K, r')


def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
consEQ = s.Eq(1, K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))
r = s.solve(consEQ, r)
r
# Out:
#   File "<ipython-input-3-fea16b4d6bd9>", line 12
#     r = s.solve(consEQ, r)
#     ^
# SyntaxError: invalid syntax

# %%
import sympy as s


theta, K, r = s.symbols('theta, K, r')


def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
consEQ = s.Eq(1, K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))
s.solve(consEQ, r)
# Out:
#   File "<ipython-input-4-0457a9532681>", line 12
#     s.solve(consEQ, r)
#     ^
# SyntaxError: invalid syntax

# %%
s.solve(x**2, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
# ----> 1 s.solve(x**2, 4)
#
# NameError: name 'x' is not defined

# %%
x = s.Symbol('x')
s.solve(x**2, 4)
# Out:
# []

# %%
x = s.Symbol('x')
s.solve(x * 2, 4)
# Out:
# []

# %%
x = s.Symbol('x')
s.solve(Eq(x * 2, 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       1 x = s.Symbol('x')
# ----> 2 s.solve(Eq(x * 2, 4))
#
# NameError: name 'Eq' is not defined

# %%
import sympy as s
x = s.Symbol('x')
s.solve(Eq(x * 2, 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       1 import sympy as s
#       2 x = s.Symbol('x')
# ----> 3 s.solve(Eq(x * 2, 4))
#
# NameError: name 'Eq' is not defined

# %%
import sympy as s
from sympy import *
x = s.Symbol('x')
s.solve(Eq(x * 2, 4))
# Out:
# [2]

# %%
import sympy as s
from sympy import Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')


def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
consEQ = s.Eq(1, K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))
s.solve(consEQ, r)
# Out:
#   File "<ipython-input-11-838711193d68>", line 12
#     s.solve(consEQ, r)
#     ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')


def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
consEQ = s.Eq(1, K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))
s.solve(consEQ, r)
# Out:
#   File "<ipython-input-12-a3c3064f0f0f>", line 12
#     s.solve(consEQ, r)
#     ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')


def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)
consEQ = Eq(1, rightHand)
s.solve(consEQ, r)
# Out:
#   File "<ipython-input-13-c9879b359a76>", line 12
#     consEQ = Eq(1, rightHand)
#          ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')


def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)
consEQ = Eq(1, rightHand)
solve(consEQ, r)
# Out:
#   File "<ipython-input-14-c0da3a79f51c>", line 12
#     consEQ = Eq(1, rightHand)
#          ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')

def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)
consEQ = s.Equality(1, rightHand)
s.solve(consEQ, r)
# Out:
#   File "<ipython-input-15-8be77c02fca7>", line 11
#     consEQ = s.Equality(1, rightHand)
#          ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')

def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)
consistency = s.Equality(1, rightHand)
s.solve(consEQ, r)
# Out:
#   File "<ipython-input-16-299945591834>", line 11
#     consistency = s.Equality(1, rightHand)
#               ^
# SyntaxError: invalid syntax

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta, K, r')

def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)
consistency = Equality(1, rightHand)
solve(consEQ, r)
# Out:
#   File "<ipython-input-17-353059e2b2e3>", line 12
#     consistency = Equality(1, rightHand)
#               ^
# SyntaxError: invalid syntax

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')

def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

consistency = Equality(1, rightHand)
solve(consEQ, r)
# Out:
#   File "<ipython-input-18-e93d07260aef>", line 13
#     consistency = Equality(1, rightHand)
#               ^
# SyntaxError: invalid syntax

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(math.sqrt(2 * math.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

consistency = Equality(1, rightHand)
solve(consEQ, r)
# Out:
#   File "<ipython-input-19-5fc3bb5673d6>", line 14
#     consistency = Equality(1, rightHand)
#               ^
# SyntaxError: invalid syntax

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

consistency = Equality(1, rightHand)
solve(consEQ, r)
# Out:
#   File "<ipython-input-20-1c2bfb043659>", line 14
#     consistency = Equality(1, rightHand)
#               ^
# SyntaxError: invalid syntax

# %%
s.pi
# Out:
# pi

# %%
s.e
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
# ----> 1 s.e
#
# AttributeError: module 'sympy' has no attribute 'e'

# %%
math.e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
# ----> 1 math.e
#
# NameError: name 'math' is not defined

# %%
import math
math.e
# Out:
# 2.718281828459045

# %%
s.euler
# Out:
# euler

# %%
print(s.euler)
# Out:
# euler

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

# integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
# rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

consistency = Equality(1, rightHand)
solve(consistency, r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#      12 # rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)
#      13
# ---> 14 consistency = Equality(1, rightHand)
#      15 solve(consistency, r)
#      16
#
# NameError: name 'rightHand' is not defined

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))

rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

consistency = Equality(1, rightHand)
solve(consistency, r)
# Out:
#   File "<ipython-input-28-83defed3acf4>", line 15
#     consistency = Equality(1, rightHand)
#               ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import *

s.sq
x = s.Symbol('x')
s.solve(Eq(x * 2, 4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       2 from sympy import *
#       3
# ----> 4 s.sq
#       5 x = s.Symbol('x')
#       6 s.solve(Eq(x * 2, 4))
#
# AttributeError: module 'sympy' has no attribute 'sq'

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
s.solve(Eq(x * 2, 4))
# Out:
# [2]

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
eqn = Eq(x * 2, 4)
s.solve(eqn)
# Out:
# [2]

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

eqn = Equality(1, rightHand)
solve(eqn, r)
# Out:
#   File "<ipython-input-32-3e76c1a14fb9>", line 14
#     eqn = Equality(1, rightHand)
#       ^
# SyntaxError: invalid syntax

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2)

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
#   File "<ipython-input-33-99bc81395db9>", line 14
#     eqn = Eq(1, rightHand)
#       ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
eqn = Eq(s.integrate(-x**2), (0,1))

s.solve(eqn)
# Out:
# []

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
# eqn = Eq(

# s.solve(eqn)

s.integrate(-x**2), (0,1)
# Out:
# (-x**3/3, (0, 1))

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
# eqn = Eq(

# s.solve(eqn)

s.integrate(-x**2), (x,0,1)
# Out:
# (-x**3/3, (x, 0, 1))

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
# eqn = Eq(

# s.solve(eqn)

s.integrate(-x**2), (x,0,1))
# Out:
#   File "<ipython-input-37-7e419922fb93>", line 10
#     s.integrate(-x**2), (x,0,1))
#                                ^
# SyntaxError: invalid syntax

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
# eqn = Eq(

# s.solve(eqn)

s.integrate(-x**2, (x,0,1))
# Out:
# -1/3

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       9     1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)
#      10
# ---> 11 integrand = (s.cos(theta))**2 * g(K * r * math.sin(theta))
#      12 rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))
#      13
#
# C:\Anaconda3\lib\site-packages\sympy\core\expr.py in __float__(self)
#     323         if result.is_number and result.as_real_imag()[1]:
#     324             raise TypeError("can't convert complex to float")
# --> 325         raise TypeError("can't convert expression to float")
#     326
#     327     def __complex__(self):
#
# TypeError: can't convert expression to float

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = s.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
#   File "<ipython-input-40-6413e3fc1b33>", line 11
#     integrand = s.cos(theta))**2 * g(K * r * math.sin(theta))
#                             ^
# SyntaxError: invalid syntax

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

integrand = (math.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       9     1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)
#      10
# ---> 11 integrand = (math.cos(theta))**2 * g(K * r * math.sin(theta))
#      12 rightHand = K * s.integrate(integrand, (theta, -math.pi/2, math.pi/2))
#      13
#
# C:\Anaconda3\lib\site-packages\sympy\core\expr.py in __float__(self)
#     323         if result.is_number and result.as_real_imag()[1]:
#     324             raise TypeError("can't convert complex to float")
# --> 325         raise TypeError("can't convert expression to float")
#     326
#     327     def __complex__(self):
#
# TypeError: can't convert expression to float

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(x):
    1/(s.sqrt(2 * s.pi)) * math.e**(-1/2 * x**2)

# integrand = (math.cos(theta))**2 * g(K * r * math.sin(theta))
rightHand = K * s.integrate((math.cos(theta))**2 * g(K * r * math.sin(theta)), (theta, -math.pi/2, math.pi/2))

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#      10
#      11 # integrand = (math.cos(theta))**2 * g(K * r * math.sin(theta))
# ---> 12 rightHand = K * s.integrate((math.cos(theta))**2 * g(K * r * math.sin(theta)), (theta, -math.pi/2, math.pi/2))
#      13
#      14 eqn = Eq(1, rightHand)
#
# C:\Anaconda3\lib\site-packages\sympy\core\expr.py in __float__(self)
#     323         if result.is_number and result.as_real_imag()[1]:
#     324             raise TypeError("can't convert complex to float")
# --> 325         raise TypeError("can't convert expression to float")
#     326
#     327     def __complex__(self):
#
# TypeError: can't convert expression to float

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(o):
    1/(math.sqrt(2 * s.pi))     *     math.e**(-1/2 * o**2)

integrand = (math.cos(theta))**2       *     g(K * r * math.sin(theta))

rightHand = K     *      integrate(integrand, (theta, -math.pi/2, math.pi/2))

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Google Drive\r-master\1+2 CS\project ME\oscillators.py in <module>
#       9     1/(math.sqrt(2 * s.pi))     *     math.e**(-1/2 * o**2)
#      10
# ---> 11 integrand = (math.cos(theta))**2       *     g(K * r * math.sin(theta))
#      12
#      13 rightHand = K     *      integrate(integrand, (theta, -math.pi/2, math.pi/2))
#
# C:\Anaconda3\lib\site-packages\sympy\core\expr.py in __float__(self)
#     323         if result.is_number and result.as_real_imag()[1]:
#     324             raise TypeError("can't convert complex to float")
# --> 325         raise TypeError("can't convert expression to float")
#     326
#     327     def __complex__(self):
#
# TypeError: can't convert expression to float

# %%
import sympy as s
from sympy import *


x = s.Symbol('x')
# eqn = Eq(

# s.solve(eqn)

integrate(-x**2, (x,0,1))
# Out:
# -1/3

# %%
import sympy as s
import math
from sympy import * # Eq, solve, symbols

theta, K, r = s.symbols('theta K r')
consistency = s.Function('consistency')

def g(o):
    1/(math.sqrt(2 * s.pi))     *     math.e**(-1/2 * o**2)

# integrand = (math.cos(theta))**2       *     g(K * r * math.sin(theta))
integrand = theta**2

rightHand = K     *      integrate(integrand, (theta, -math.pi/2, math.pi/2))

eqn = Eq(1, rightHand)
solve(eqn, r)
# Out:
# []

# %%
import math
import random as rand
import numpy as np
import matplotlib.pyplot as plt
from numba import jit, double
# from concurrent.futures import ThreadPoolExecutor
# from copy import deepcopy
import time



############################################### options for optimisation #############################################
#
# jit
# 
# double sum -> even better, average phase, then ...? wait what?
# 
#####################################################################################################################





class Oscillator:

    def __init__(self, initPhase, omega):
        self.omega = omega
        self.lastTheta = 0.0                                            # gets value immediately, but instantiate type
        self.currentTheta = initPhase                                   # handed over immediately on first run to lastTheta




class OscPopulation:

    def __init__(self, omegaDistr = 'normal'):
        # list of objects  
        self.list_os = np.zeros(N, dtype = Oscillator)                      # pre-allocate with fixed size -> speed gain?
        self.omegaDistr = omegaDistr
       
       # complete initialisation
        for n in range(N):
            if omegaDistr == 'normal': omega = rand.normalvariate(0,1)
            elif omegaDistr == 'uniform': omega = rand.uniform(-0.5, 0.5)
                    
            initPhase = rand.uniform(0, math.tau)        
            
            self.list_os[n] = Oscillator(initPhase, omega)

        print('oscillators initialised with', omegaDistr.upper(), 'distibution of omegas' )



    def reRandomise(self):

        for n in range(N):
            # omega
            if self.omegaDistr == 'normal': newOmega = rand.normalvariate(0.0,1.0)
            elif self.omegaDistr == 'uniform': newOmega = rand.uniform(-0.5, 0.5)  
            # theta
            newInitPhase = rand.uniform(0, math.tau)      
            
            self.list_os[n].omega = newOmega
            self.list_os[n].lastTheta = 0.0                                             # gets value immediately, but instantiate type
            self.list_os[n].currenTtheta = newInitPhase                                    # handed over immediately on first run to lastTheta
            

        print('## 3 variables re-randomised ##' )        



    ############ calculate r ############
    def calc_r(self):                                       
        
        ###### one way to do it #######
        # complex sum of all phases 
        # realSum = 0 
        # imaginarySum = 0

        # for n in range(N): 
        #     realSum += math.cos(self.list_os[n].theta[-1])
        #     imaginarySum += math.sin(self.list_os[n].theta[-1])
        
        # realSum = realSum/N 
        # imaginarySum = imaginarySum/N
        # r = math.sqrt(realSum * realSum + imaginarySum * imaginarySum)


        ###### another way to do it #######
        sum = 0.0 + 0.0j
        for n in range(N):
            sum += math.e**(1.0j * self.list_os[n].currentTheta)                             
        sum = sum / N 

        # r = math.sqrt(sum.real**2 + sum.imag**2)
        r = abs(sum)
        
        return r

    

    # wrapper method
    def stepAll(self, K):

        # getter: from objects
        lastThetaList = []
        currentThetaList = []
        omegaList = []

        for n in range(N):
            lastThetaList.append(self.list_os[n].lastTheta)
            currentThetaList.append(self.list_os[n].currentTheta)
            omegaList.append(self.list_os[n].omega)

        # converting
        lastThetaArray = np.array(lastThetaList)
        currentThetaArray = np.array(currentThetaList)
        omegaArray = np.array(omegaList)

        # up until here its totally fine, values are correctly transmitted

        # calculating, handing over
        newLastThetaArray, newCurrentThetaArray = self._stepAll(lastThetaArray, currentThetaArray, omegaArray, K)

        # conversion, just in case
        lastThetaList = newLastThetaArray.tolist()
        currentThetaList = newCurrentThetaArray.tolist()



        # setter: back to OOP
        for n in range(N):
            self.list_os[n].lastTheta = lastThetaList[n]
            self.list_os[n].currentTheta = currentThetaList[n]

    
    
    # step FOR time t -> use t-1 ####################################
    @staticmethod
    @jit(nopython = True)            #('double[:](double[:], double[:], double[:], int8)', nopython = True)
    def _stepAll(lastThetaArray, currentThetaArray, omegaArray, K):
        
        for n in range(N):                                                                  # step through time -> hand over value
            lastThetaArray[n] = currentThetaArray[n]

        # calculate new thetas
        for n in range(N):
            
            sum = 0.0
            for j in range(N):                                                              # calculate differential sum for ONE oscillator n for time t
                sum += math.sin(lastThetaArray[j] - lastThetaArray[n])                  

            theta_dot_t = omegaArray[n] + K/N * sum                                 # theta_dot_t for oscillator n
            
            theta_t = lastThetaArray[n] + dt * theta_dot_t                          # new theta for oscillator n -> euler step

            currentThetaArray[n] = theta_t                                          # going down list of objects, pick object, dial into theta list, append

        return lastThetaArray, currentThetaArray




    def runK(self):
        
        r_critList= []
                        
        for K in K_range:  
            self.reRandomise()

            for t in t_range:
                self.stepAll(K)

            r_crit = self.calc_r()
            r_critList.append(r_crit)
            print('K = ' + str(round(K,3)) + ' | r_crit = ' + str(round(r_crit, 3)))
            
        return r_critList
                


    def runT(self, K):
        rList = []

        for t in t_range:
            # step all oscillators forward INTO timeperiod t
            self.stepAll(K)

            # calculate the population's coherence at each time step
            r = self.calc_r()
            rList.append(r)
                    
            # status
            if t % 10 == 0: print('t =', t, 'done') 
    
    
        return rList

# %%
# %%time


N = 1000             # 1000 
T = 100             # 100
dt = 0.01
K = 4
dk = 0.1

numberOfTimes = int(T/dt)
numberOfK = int(K/dk)
t_range = [round(i * dt, 4) for i in range(numberOfTimes + 1)]
K_range =  [round(i * dk, 4) for i in range(numberOfK + 1)]            


pop1 = OscPopulation('normal')
r_critList = pop1.runK() 


# graphics 
plt.figure(figsize = (10,6))
plt.title('System state diagram')
plt.xlim(0, 4)
plt.ylim(0, 1)
plt.xlabel('coupling strength K')
plt.ylabel('coherence r')

plt.plot(K_range, r_critList, 'ko')
filename = 'graphics/1_K-vs-r' + '_omegaDistr=' + pop1.omegaDistr + '_N=' + str(N) + '_' + str(int(time.time())) + '.pdf'
plt.savefig(filename, dpi = 200, bbox_inches = 'tight')
plt.show()
# Out:
# oscillators initialised with NORMAL distibution of omegas
# ## 3 variables re-randomised ##
# K = 0.0 | r_crit = 0.015
# ## 3 variables re-randomised ##
# K = 0.1 | r_crit = 0.039
# ## 3 variables re-randomised ##
# K = 0.2 | r_crit = 0.024
# ## 3 variables re-randomised ##
# K = 0.3 | r_crit = 0.027
# ## 3 variables re-randomised ##
# K = 0.4 | r_crit = 0.023
# ## 3 variables re-randomised ##
# K = 0.5 | r_crit = 0.053
# ## 3 variables re-randomised ##
# K = 0.6 | r_crit = 0.063
# ## 3 variables re-randomised ##
# K = 0.7 | r_crit = 0.045
# ## 3 variables re-randomised ##
# K = 0.8 | r_crit = 0.039
# ## 3 variables re-randomised ##
# K = 0.9 | r_crit = 0.032
# ## 3 variables re-randomised ##
# K = 1.0 | r_crit = 0.045
# ## 3 variables re-randomised ##
# K = 1.1 | r_crit = 0.03
# ## 3 variables re-randomised ##
# K = 1.2 | r_crit = 0.123
# ## 3 variables re-randomised ##
# K = 1.3 | r_crit = 0.072
# ## 3 variables re-randomised ##
# K = 1.4 | r_crit = 0.161
# ## 3 variables re-randomised ##
# K = 1.5 | r_crit = 0.016
# ## 3 variables re-randomised ##
# K = 1.6 | r_crit = 0.541
# ## 3 variables re-randomised ##
# K = 1.7 | r_crit = 0.311
# ## 3 variables re-randomised ##
# K = 1.8 | r_crit = 0.59
# ## 3 variables re-randomised ##
# K = 1.9 | r_crit = 0.641
# ## 3 variables re-randomised ##
# K = 2.0 | r_crit = 0.723
# ## 3 variables re-randomised ##
# K = 2.1 | r_crit = 0.751
# ## 3 variables re-randomised ##
# K = 2.2 | r_crit = 0.777
# ## 3 variables re-randomised ##
# K = 2.3 | r_crit = 0.825
# ## 3 variables re-randomised ##
# K = 2.4 | r_crit = 0.865
# ## 3 variables re-randomised ##
# K = 2.5 | r_crit = 0.85
# ## 3 variables re-randomised ##
# K = 2.6 | r_crit = 0.908
# ## 3 variables re-randomised ##
# K = 2.7 | r_crit = 0.893
# ## 3 variables re-randomised ##
# K = 2.8 | r_crit = 0.893
# ## 3 variables re-randomised ##
# K = 2.9 | r_crit = 0.918
# ## 3 variables re-randomised ##
# K = 3.0 | r_crit = 0.928
# ## 3 variables re-randomised ##
# K = 3.1 | r_crit = 0.933
# ## 3 variables re-randomised ##
# K = 3.2 | r_crit = 0.94
# ## 3 variables re-randomised ##
# K = 3.3 | r_crit = 0.936
# ## 3 variables re-randomised ##
# K = 3.4 | r_crit = 0.943
# ## 3 variables re-randomised ##
# K = 3.5 | r_crit = 0.951
# ## 3 variables re-randomised ##
# K = 3.6 | r_crit = 0.953
# ## 3 variables re-randomised ##
# K = 3.7 | r_crit = 0.955
# ## 3 variables re-randomised ##
# K = 3.8 | r_crit = 0.956
# ## 3 variables re-randomised ##
# K = 3.9 | r_crit = 0.964
# ## 3 variables re-randomised ##
# K = 4.0 | r_crit = 0.963
# Wall time: 1h 30min 48s

# %%
# %%time


N = 1000             # 1000
T = 100             # 100
dt = 0.01

numberOfTimes = int(T/dt)
t_range = [round(i * dt, 4) for i in range(numberOfTimes + 1)]      
K_range = [1, 2, 3]

rLists = [[]]

for K in K_range:
    pop2 = OscPopulation('normal')
    rList = pop2.runT(K)

    rLists.append(rList)





### graphing ###
plt.figure(figsize = (10,6))
plt.title('Evolution of r')
plt.ylim(0, 1)
plt.xlabel('time t')
plt.ylabel('coherence r')

for K in K_range:
    plt.plot(t_range, rLists[K], label = 'K = ' + str(K))
plt.legend()
filename = 'graphics/2_t-vs-r' + '_omegaDistr=' + pop2.omegaDistr + '_N=' + str(N) + '_' + str(int(time.time())) + '.pdf'
plt.savefig(filename, dpi = 200, bbox_inches = 'tight')
plt.show()
# Out:
# oscillators initialised with NORMAL distibution of omegas
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# oscillators initialised with NORMAL distibution of omegas
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# oscillators initialised with NORMAL distibution of omegas
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# Wall time: 6min 51s

# %%
# %%time


N = 2000                   # 2000    - 100, 100, took 6min
T = 200                   # 200
dt = 0.05
Kmax = 2.0
dk = 0.03

numberOfTimes = int(T/dt)
numberOfK = int(Kmax/dk)
t_range = [round(i * dt, 4) for i in range(numberOfTimes + 1)]
K_range =  [round(i * dk, 4) for i in range(numberOfK + 1)]  

pop3 = OscPopulation('uniform')
r_critList = pop3.runK() 


# graphics 
plt.figure(figsize = (10,6))
plt.title('System state diagram')
plt.xlim(0, 4)
plt.ylim(0, 1)
plt.xlabel('coupling strength K')
plt.ylabel('coherence r')

plt.plot(K_range, r_critList, 'ko')
filename = 'graphics/3_K-vs-r' + '_omegaDistr=' + pop3.omegaDistr + '_N=' + str(N) + '_' + str(int(time.time())) + '.pdf'
plt.savefig(filename, dpi = 200, bbox_inches = 'tight')
plt.show()


# graphics 
plt.figure(figsize = (10,6))
plt.title('System state diagram')
plt.ylim(0, 1)
plt.xlabel('coupling strength K')
plt.ylabel('coherence r')

plt.plot(K_range, r_critList, 'ko')
filename = 'graphics/3_K-vs-r_' + 'omegaDistr=' + pop3.omegaDistr + '_zoomed' + '_N=' + str(N) + '_' + str(int(time.time())) + '.pdf'
plt.savefig(filename, dpi = 200, bbox_inches = 'tight')
plt.show()
# Out:
# oscillators initialised with UNIFORM distibution of omegas
# ## 3 variables re-randomised ##
# K = 0.0 | r_crit = 0.006
# ## 3 variables re-randomised ##
# K = 0.03 | r_crit = 0.018
# ## 3 variables re-randomised ##
# K = 0.06 | r_crit = 0.015
# ## 3 variables re-randomised ##
# K = 0.09 | r_crit = 0.004
# ## 3 variables re-randomised ##
# K = 0.12 | r_crit = 0.018
# ## 3 variables re-randomised ##
# K = 0.15 | r_crit = 0.025
# ## 3 variables re-randomised ##
# K = 0.18 | r_crit = 0.032
# ## 3 variables re-randomised ##
# K = 0.21 | r_crit = 0.022
# ## 3 variables re-randomised ##
# K = 0.24 | r_crit = 0.032
# ## 3 variables re-randomised ##
# K = 0.27 | r_crit = 0.027
# ## 3 variables re-randomised ##
# K = 0.3 | r_crit = 0.024
# ## 3 variables re-randomised ##
# K = 0.33 | r_crit = 0.037
# ## 3 variables re-randomised ##
# K = 0.36 | r_crit = 0.006
# ## 3 variables re-randomised ##
# K = 0.39 | r_crit = 0.055
# ## 3 variables re-randomised ##
# K = 0.42 | r_crit = 0.043
# ## 3 variables re-randomised ##
# K = 0.45 | r_crit = 0.05
# ## 3 variables re-randomised ##
# K = 0.48 | r_crit = 0.068
# ## 3 variables re-randomised ##
# K = 0.51 | r_crit = 0.049
# ## 3 variables re-randomised ##
# K = 0.54 | r_crit = 0.03
# ## 3 variables re-randomised ##
# K = 0.57 | r_crit = 0.041
# ## 3 variables re-randomised ##
# K = 0.6 | r_crit = 0.09
# ## 3 variables re-randomised ##
# K = 0.63 | r_crit = 0.085
# ## 3 variables re-randomised ##
# K = 0.66 | r_crit = 0.248
# ## 3 variables re-randomised ##
# K = 0.69 | r_crit = 0.432
# ## 3 variables re-randomised ##
# K = 0.72 | r_crit = 0.437
# ## 3 variables re-randomised ##
# K = 0.75 | r_crit = 0.449
# ## 3 variables re-randomised ##
# K = 0.78 | r_crit = 0.46
# ## 3 variables re-randomised ##
# K = 0.81 | r_crit = 0.461
# ## 3 variables re-randomised ##
# K = 0.84 | r_crit = 0.462
# ## 3 variables re-randomised ##
# K = 0.87 | r_crit = 0.465
# ## 3 variables re-randomised ##
# K = 0.9 | r_crit = 0.468
# ## 3 variables re-randomised ##
# K = 0.93 | r_crit = 0.471
# ## 3 variables re-randomised ##
# K = 0.96 | r_crit = 0.472
# ## 3 variables re-randomised ##
# K = 0.99 | r_crit = 0.478
# ## 3 variables re-randomised ##
# K = 1.02 | r_crit = 0.478
# ## 3 variables re-randomised ##
# K = 1.05 | r_crit = 0.48
# ## 3 variables re-randomised ##
# K = 1.08 | r_crit = 0.482
# ## 3 variables re-randomised ##
# K = 1.11 | r_crit = 0.486
# ## 3 variables re-randomised ##
# K = 1.14 | r_crit = 0.484
# ## 3 variables re-randomised ##
# K = 1.17 | r_crit = 0.484
# ## 3 variables re-randomised ##
# K = 1.2 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.23 | r_crit = 0.491
# ## 3 variables re-randomised ##
# K = 1.26 | r_crit = 0.489
# ## 3 variables re-randomised ##
# K = 1.29 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.32 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.35 | r_crit = 0.489
# ## 3 variables re-randomised ##
# K = 1.38 | r_crit = 0.492
# ## 3 variables re-randomised ##
# K = 1.41 | r_crit = 0.489
# ## 3 variables re-randomised ##
# K = 1.44 | r_crit = 0.487
# ## 3 variables re-randomised ##
# K = 1.47 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.5 | r_crit = 0.49
# ## 3 variables re-randomised ##
# K = 1.53 | r_crit = 0.489
# ## 3 variables re-randomised ##
# K = 1.56 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.59 | r_crit = 0.487
# ## 3 variables re-randomised ##
# K = 1.62 | r_crit = 0.487
# ## 3 variables re-randomised ##
# K = 1.65 | r_crit = 0.487
# ## 3 variables re-randomised ##
# K = 1.68 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.71 | r_crit = 0.487
# ## 3 variables re-randomised ##
# K = 1.74 | r_crit = 0.488
# ## 3 variables re-randomised ##
# K = 1.77 | r_crit = 0.489
# ## 3 variables re-randomised ##
# K = 1.8 | r_crit = 0.49
# ## 3 variables re-randomised ##
# K = 1.83 | r_crit = 0.489
# ## 3 variables re-randomised ##
# K = 1.86 | r_crit = 0.49
# ## 3 variables re-randomised ##
# K = 1.89 | r_crit = 0.49
# ## 3 variables re-randomised ##
# K = 1.92 | r_crit = 0.492
# ## 3 variables re-randomised ##
# K = 1.95 | r_crit = 0.494
# ## 3 variables re-randomised ##
# K = 1.98 | r_crit = 0.494
# Wall time: 1h 54s

# %%
# %%time
# --> same natural frequencies as first time, but start at different positions every time

N = 2000                      # 2000
T = 200                      # 200
dt = 0.05
runs = 10 

numberOfTimes = int(T/dt)
t_range = [round(i * dt, 4) for i in range(numberOfTimes + 1)]
K = 1               # 1

fixedOmegaPop = OscPopulation('uniform')
# savedOmegas = deepcopy(fixedOmegaPop)
rLists = []


for run in range(runs):
    _fixedOmegaPop = OscPopulation('uniform')

    for n in range(N): 
        _fixedOmegaPop.list_os[n].omega = fixedOmegaPop.list_os[n].omega
    print('original omegas restored')

    rNewList = _fixedOmegaPop.runT(K)
    rLists.append(rNewList)

    print('############# run', str(run), 'done #############\n') 


### graphing ###
plt.figure(figsize = (10,6))
plt.title('Evolution of r')
plt.ylim(0,1)
plt.xlabel('time t')
plt.ylabel('coherence r')

for run in range(runs):
    plt.plot(t_range, rLists[run])

filename = 'graphics/4_t-vs-r' + '_fixedOmegas' + '_omegaDistr=' + fixedOmegaPop.omegaDistr + '_N=' + str(N) + '_' + str(int(time.time())) + '.pdf'
plt.savefig(filename, dpi = 200, bbox_inches = 'tight')
plt.show()
# Out:
# oscillators initialised with UNIFORM distibution of omegas
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 0 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 1 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 2 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 3 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 4 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 5 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 6 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 7 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 8 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original omegas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 9 done #############
# Wall time: 9min 29s

# %%
# %%time
# --> have same positions as first run, but the natural frequencies get changed

N = 2000                  # 2000
T = 200                 # 200
dt = 0.05
runs = 10

numberOfTimes = int(T/dt)
t_range = [round(i * dt, 4) for i in range(numberOfTimes + 1)]
K = 1


fixedThetaPop = OscPopulation('uniform')
# savedThetas = deepcopy(fixedThetaPop)
rLists = []


for run in range(runs):
    _fixedThetaPop = OscPopulation('uniform')

    for n in range(N):
        _fixedThetaPop.list_os[n].currentTheta = fixedThetaPop.list_os[n].currentTheta
        _fixedThetaPop.list_os[n].lastTheta = 0.0
    print('original thetas restored')

    rNewList = _fixedThetaPop.runT(K)
    rLists.append(rNewList)

    print('############# run', str(run), 'done #############\n')


### graphing ###
plt.figure(figsize = (10,6))
plt.title('Evolution of r')
plt.ylim(0,1)
plt.xlabel('time t')
plt.ylabel('coherence r')

for run in range(runs):
    plt.plot(t_range, rLists[run])

filename = 'graphics/5_t-vs-r' + '_fixedThetas' + '_omegaDistr=' + fixedThetaPop.omegaDistr + '_N=' + str(N) + '_' + str(int(time.time())) + '.pdf'
plt.savefig(filename, dpi = 200, bbox_inches = 'tight')
plt.show()
# Out:
# oscillators initialised with UNIFORM distibution of omegas
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 0 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 1 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 2 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 3 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 4 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 5 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 6 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 7 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 8 done #############
#
# oscillators initialised with UNIFORM distibution of omegas
# original thetas restored
# t = 0.0 done
# t = 10.0 done
# t = 20.0 done
# t = 30.0 done
# t = 40.0 done
# t = 50.0 done
# t = 60.0 done
# t = 70.0 done
# t = 80.0 done
# t = 90.0 done
# t = 100.0 done
# t = 110.0 done
# t = 120.0 done
# t = 130.0 done
# t = 140.0 done
# t = 150.0 done
# t = 160.0 done
# t = 170.0 done
# t = 180.0 done
# t = 190.0 done
# t = 200.0 done
# ############# run 9 done #############
# Wall time: 10min 23s
